# %% [markdown]
# What is the `compose_combinator`?

# %% [markdown]
# !! It is only meant to be use by library authors. It is used to implement other combinators such as `switch_combinator`, the joint `mixture_combinator`, and `repeat_combinator`.

# %%
# Example of rewriting the `mixture_combinator` using the `compose_combinator` and `switch_combinator` functions
from genjax._src.core.generative import GenerativeFunction
from genjax._src.generative_functions.combinators.compose_combinator import (
    compose_combinator,
)
from genjax._src.generative_functions.combinators.switch_combinator import (
    switch_combinator,
)
from genjax import categorical, gen, normal, mixture_combinator
import jax.random as random
from genjax._src.core.typing import typecheck, List


@typecheck
def new_mixture_combinator(
    *gen_fns: GenerativeFunction,
) -> GenerativeFunction:
    def argument_mapping(mixture_logits, *args):
        return (mixture_logits, *args)

    # Packing the generative functions using a switch combinator
    inner_combinator_closure = switch_combinator(*gen_fns)

    @gen
    def mixture_model(mixture_logits, *args):
        # The mixture combinator creates a mixture model that samples from a categorical distribution to get the index of the component to sample from
        mix_idx = categorical(logits=mixture_logits) @ "mixture_component"
        # And then calls the inner combinator closure to sample from the selected component
        v = inner_combinator_closure(mix_idx, *args) @ "component_sample"
        return v

    # The `compose_combinator` function is used to wrap the mixture model function with the argument mapping function to create a new generative function
    return compose_combinator(
        mixture_model,
        pre=argument_mapping,
        info="Derived combinator (Mixture)",
    )

# To add a version accessible as model.new_mix:
def new_mix(
    self,
    branches: List["GenerativeFunction"],
    *args,
) -> "GenerativeFunction":
    return (
        new_mixture_combinator(self, *branches)(*args)
        if args
        else new_mixture_combinator(self, *branches)
    )

# Testing the rewritten version on an example
@gen
def mixture_model(p):
    logits = (0.4, 0.6)
    arg_1 = (p,)
    arg_2 = (p,)
    component_1 = gen(lambda p: normal(p, 0.1) @ "x")
    component_2 = gen(lambda p: normal(p, 0.2) @ "y")
    a = new_mixture_combinator(component_1, component_2)(logits, arg_1, arg_2) @ "a"
    return a


key = random.PRNGKey(23)
tr = mixture_model.simulate(key, (0.4,))
print(tr.get_retval())

# Testing the version accessible as model.new_switch
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 64
#      60     return a
#      63 key = random.PRNGKey(23)
# ---> 64 tr = mixture_model.simulate(key, (0.4,))
#      65 print(tr.get_retval())
#      67 # Testing the version accessible as model.new_switch
#
#     [... skipping hidden 1 frame]
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.simulate) at 0x127c75bc0>:55, in simulate(__beartype_object_4653542080, __beartype_get_violation, __beartype_conf, __beartype_object_4375655408, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:524, in StaticGenerativeFunction.simulate(self, key, args)
#     514 @GenerativeFunction.gfi_boundary
#     515 @typecheck
#     516 def simulate(
#    (...)
#     519     args: Tuple,
#     520 ) -> StaticTrace:
#     521     syntax_sugar_handled = push_trace_overload_stack(
#     522         handler_trace_with_static, self.source
#     523     )
# --> 524     (args, retval, address_visitor, address_traces, score) = simulate_transform(
#     525         syntax_sugar_handled
#     526     )(key, args)
#     527     return StaticTrace(
#     528         self,
#     529         args,
#    (...)
#     533         score,
#     534     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:274, in simulate_transform.<locals>.wrapper(key, args)
#     271 @functools.wraps(source_fn)
#     272 def wrapper(key, args):
#     273     stateful_handler = SimulateHandler(key)
# --> 274     retval = forward(source_fn)(stateful_handler, *args)
#     275     (
#     276         address_visitor,
#     277         address_traces,
#     278         score,
#     279     ) = stateful_handler.yield_state()
#     280     return (
#     281         args,
#     282         retval,
#    (...)
#     285         score,
#     286     )
#
# File <@beartype(genjax._src.core.interpreters.forward.forward.wrapped) at 0x1358a9580>:32, in wrapped(__beartype_object_4376412208, __beartype_get_violation, __beartype_conf, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:257, in forward.<locals>.wrapped(stateful_handler, *args)
#     253 @functools.wraps(f)
#     254 @typecheck
#     255 def wrapped(stateful_handler: StatefulHandler, *args):
#     256     interpreter = ForwardInterpreter()
# --> 257     return interpreter.run_interpreter(
#     258         stateful_handler,
#     259         f,
#     260         *args,
#     261     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:240, in ForwardInterpreter.run_interpreter(self, stateful_handler, fn, *args, **kwargs)
#     237 def _inner(*args):
#     238     return fn(*args, **kwargs)
# --> 240 _closed_jaxpr, (flat_args, _, out_tree) = stage(_inner)(*args)
#     241 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
#     242 flat_out = self._eval_jaxpr_forward(
#     243     stateful_handler,
#     244     _jaxpr,
#     245     consts,
#     246     flat_args,
#     247 )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:125, in stage.<locals>.wrapped(*args, **kwargs)
#     123 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#     124 flat_avals = safe_map(get_shaped_aval, flat_args)
# --> 125 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#     126 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:112, in cached_stage_dynamic(flat_fun, in_avals)
#     110 @lu.cache
#     111 def cached_stage_dynamic(flat_fun, in_avals):
# --> 112     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#     113     typed_jaxpr = jc.ClosedJaxpr(jaxpr, consts)
#     114     return typed_jaxpr
#
#     [... skipping hidden 5 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:238, in ForwardInterpreter.run_interpreter.<locals>._inner(*args)
#     237 def _inner(*args):
# --> 238     return fn(*args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:993, in push_trace_overload_stack.<locals>.wrapped(*args)
#     991 def wrapped(*args):
#     992     GLOBAL_TRACE_OP_HANDLER_STACK.append(handler)
# --> 993     ret = fn(*args)
#     994     GLOBAL_TRACE_OP_HANDLER_STACK.pop()
#     995     return ret
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/pytree.py:474, in Closure.__call__(self, *args, **kwargs)
#     473 def __call__(self, *args, **kwargs):
# --> 474     return self.fn(*self.dyn_args, *args, **kwargs)
#
# Cell In[3], line 59, in mixture_model(p)
#      57 component_1 = gen(lambda p: normal(p, 0.1) @ "x")
#      58 component_2 = gen(lambda p: normal(p, 0.2) @ "y")
# ---> 59 a = new_mixture_combinator(component_1, component_2)(logits, arg_1, arg_2) @ "a"
#      60 return a
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:1049, in GenerativeFunctionClosure.__matmul__(self, addr)
#    1043     return handle_off_trace_stack(
#    1044         addr,
#    1045         maybe_kwarged_gen_fn,
#    1046         (self.args, self.kwargs),
#    1047     )
#    1048 else:
# -> 1049     return handle_off_trace_stack(
#    1050         addr,
#    1051         self.gen_fn,
#    1052         self.args,
#    1053     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:983, in handle_off_trace_stack(addr, gen_fn, args)
#     981 if GLOBAL_TRACE_OP_HANDLER_STACK:
#     982     handler = GLOBAL_TRACE_OP_HANDLER_STACK[-1]
# --> 983     return handler(addr, gen_fn, args)
#     984 else:
#     985     raise Exception(
#     986         "Attempting to invoke trace outside of a tracing context.\nIf you want to invoke the generative function closure, and recieve a return value,\ninvoke it with a key."
#     987     )
#
# File <@beartype(genjax._src.generative_functions.static.handler_trace_with_static) at 0x127c75940>:91, in handler_trace_with_static(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4376485712, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:467, in handler_trace_with_static(addr, gen_fn, args)
#     461 @typecheck
#     462 def handler_trace_with_static(
#     463     addr: StaticAddressComponent | StaticAddress,
#     464     gen_fn: GenerativeFunction,
#     465     args: Tuple,
#     466 ):
# --> 467     return trace(addr if isinstance(addr, tuple) else (addr,), gen_fn, args)
#
# File <@beartype(genjax._src.generative_functions.static.trace) at 0x127c63740>:89, in trace(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4376485712, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:178, in trace(addr, gen_fn, args)
#     170 """Invoke a generative function, binding its generative semantics with the current
#     171 caller.
#     172
#    (...)
#     175     gen_fn: A generative function invoked as a callee of `StaticGenerativeFunction`.
#     176 """
#     177 addr = Pytree.tree_const(addr)
# --> 178 return initial_style_bind(trace_p)(_abstract_gen_fn_call)(
#     179     addr,
#     180     gen_fn,
#     181     args,
#     182 )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:121, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     119 def wrapped(*args, **kwargs):
#     120     """Runs a function and binds it to a call primitive."""
# --> 121     _jaxpr, (flat_args, in_tree, out_tree) = stage(f)(*args, **kwargs)
#     122     outs = prim.bind(
#     123         *it.chain(_jaxpr.literals, flat_args),
#     124         _jaxpr=_jaxpr.jaxpr,
#    (...)
#     128         **params,
#     129     )
#     130     return tree_util.tree_unflatten(out_tree(), outs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:125, in stage.<locals>.wrapped(*args, **kwargs)
#     123 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#     124 flat_avals = safe_map(get_shaped_aval, flat_args)
# --> 125 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#     126 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:112, in cached_stage_dynamic(flat_fun, in_avals)
#     110 @lu.cache
#     111 def cached_stage_dynamic(flat_fun, in_avals):
# --> 112     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#     113     typed_jaxpr = jc.ClosedJaxpr(jaxpr, consts)
#     114     return typed_jaxpr
#
#     [... skipping hidden 5 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:161, in _abstract_gen_fn_call(_, gen_fn, args)
#     156 def _abstract_gen_fn_call(
#     157     _: Address,
#     158     gen_fn: GenerativeFunction,
#     159     args: Tuple,
#     160 ):
# --> 161     return gen_fn.__abstract_call__(*args)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:513, in GenerativeFunction.__abstract_call__(self, *args)
#     507 def __abstract_call__(self, *args) -> Retval:
#     508     """Used to support JAX tracing, although this default implementation involves no
#     509     JAX operations (it takes a fixed-key sample from the return value).
#     510
#     511     Generative functions may customize this to improve compilation time.
#     512     """
# --> 513     return self.simulate(jax.random.PRNGKey(0), args).get_retval()
#
#     [... skipping hidden 1 frame]
#
# File <@beartype(genjax._src.generative_functions.combinators.compose_combinator.ComposeCombinator.simulate) at 0x115679580>:55, in simulate(__beartype_object_4653542080, __beartype_get_violation, __beartype_conf, __beartype_object_4376603184, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/combinators/compose_combinator.py:82, in ComposeCombinator.simulate(self, key, args)
#      74 @GenerativeFunction.gfi_boundary
#      75 @typecheck
#      76 def simulate(
#    (...)
#      79     args: Tuple,
#      80 ) -> ComposeTrace:
#      81     inner_args = self.argument_mapping(*args)
# ---> 82     tr = self.inner.simulate(key, inner_args)
#      83     inner_retval = tr.get_retval()
#      84     retval = self.retval_mapping(inner_args, inner_retval)
#
#     [... skipping hidden 1 frame]
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.simulate) at 0x127c75bc0>:55, in simulate(__beartype_object_4653542080, __beartype_get_violation, __beartype_conf, __beartype_object_4375655408, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:524, in StaticGenerativeFunction.simulate(self, key, args)
#     514 @GenerativeFunction.gfi_boundary
#     515 @typecheck
#     516 def simulate(
#    (...)
#     519     args: Tuple,
#     520 ) -> StaticTrace:
#     521     syntax_sugar_handled = push_trace_overload_stack(
#     522         handler_trace_with_static, self.source
#     523     )
# --> 524     (args, retval, address_visitor, address_traces, score) = simulate_transform(
#     525         syntax_sugar_handled
#     526     )(key, args)
#     527     return StaticTrace(
#     528         self,
#     529         args,
#    (...)
#     533         score,
#     534     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:274, in simulate_transform.<locals>.wrapper(key, args)
#     271 @functools.wraps(source_fn)
#     272 def wrapper(key, args):
#     273     stateful_handler = SimulateHandler(key)
# --> 274     retval = forward(source_fn)(stateful_handler, *args)
#     275     (
#     276         address_visitor,
#     277         address_traces,
#     278         score,
#     279     ) = stateful_handler.yield_state()
#     280     return (
#     281         args,
#     282         retval,
#    (...)
#     285         score,
#     286     )
#
# File <@beartype(genjax._src.core.interpreters.forward.forward.wrapped) at 0x1451bf1a0>:32, in wrapped(__beartype_object_4376412208, __beartype_get_violation, __beartype_conf, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:257, in forward.<locals>.wrapped(stateful_handler, *args)
#     253 @functools.wraps(f)
#     254 @typecheck
#     255 def wrapped(stateful_handler: StatefulHandler, *args):
#     256     interpreter = ForwardInterpreter()
# --> 257     return interpreter.run_interpreter(
#     258         stateful_handler,
#     259         f,
#     260         *args,
#     261     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:240, in ForwardInterpreter.run_interpreter(self, stateful_handler, fn, *args, **kwargs)
#     237 def _inner(*args):
#     238     return fn(*args, **kwargs)
# --> 240 _closed_jaxpr, (flat_args, _, out_tree) = stage(_inner)(*args)
#     241 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
#     242 flat_out = self._eval_jaxpr_forward(
#     243     stateful_handler,
#     244     _jaxpr,
#     245     consts,
#     246     flat_args,
#     247 )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:125, in stage.<locals>.wrapped(*args, **kwargs)
#     123 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#     124 flat_avals = safe_map(get_shaped_aval, flat_args)
# --> 125 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#     126 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:112, in cached_stage_dynamic(flat_fun, in_avals)
#     110 @lu.cache
#     111 def cached_stage_dynamic(flat_fun, in_avals):
# --> 112     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#     113     typed_jaxpr = jc.ClosedJaxpr(jaxpr, consts)
#     114     return typed_jaxpr
#
#     [... skipping hidden 5 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:238, in ForwardInterpreter.run_interpreter.<locals>._inner(*args)
#     237 def _inner(*args):
# --> 238     return fn(*args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:993, in push_trace_overload_stack.<locals>.wrapped(*args)
#     991 def wrapped(*args):
#     992     GLOBAL_TRACE_OP_HANDLER_STACK.append(handler)
# --> 993     ret = fn(*args)
#     994     GLOBAL_TRACE_OP_HANDLER_STACK.pop()
#     995     return ret
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/pytree.py:474, in Closure.__call__(self, *args, **kwargs)
#     473 def __call__(self, *args, **kwargs):
# --> 474     return self.fn(*self.dyn_args, *args, **kwargs)
#
# Cell In[3], line 27, in new_mixture_combinator.<locals>.mixture_model(mixture_logits, *args)
#      24 @gen
#      25 def mixture_model(mixture_logits, *args):
#      26     # The mixture combinator creates a mixture model that samples from a categorical distribution to get the index of the component to sample from
# ---> 27     mix_idx = categorical(logits=mixture_logits) @ "mixture_component"
#      28     # And then calls the inner combinator closure to sample from the selected component
#      29     v = inner_combinator_closure(mix_idx, *args) @ "component_sample"
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:1043, in GenerativeFunctionClosure.__matmul__(self, addr)
#    1041 if self.kwargs:
#    1042     maybe_kwarged_gen_fn = self.get_gen_fn_with_kwargs()
# -> 1043     return handle_off_trace_stack(
#    1044         addr,
#    1045         maybe_kwarged_gen_fn,
#    1046         (self.args, self.kwargs),
#    1047     )
#    1048 else:
#    1049     return handle_off_trace_stack(
#    1050         addr,
#    1051         self.gen_fn,
#    1052         self.args,
#    1053     )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/generative/core.py:983, in handle_off_trace_stack(addr, gen_fn, args)
#     981 if GLOBAL_TRACE_OP_HANDLER_STACK:
#     982     handler = GLOBAL_TRACE_OP_HANDLER_STACK[-1]
# --> 983     return handler(addr, gen_fn, args)
#     984 else:
#     985     raise Exception(
#     986         "Attempting to invoke trace outside of a tracing context.\nIf you want to invoke the generative function closure, and recieve a return value,\ninvoke it with a key."
#     987     )
#
# File <@beartype(genjax._src.generative_functions.static.handler_trace_with_static) at 0x127c75940>:91, in handler_trace_with_static(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4376485712, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:467, in handler_trace_with_static(addr, gen_fn, args)
#     461 @typecheck
#     462 def handler_trace_with_static(
#     463     addr: StaticAddressComponent | StaticAddress,
#     464     gen_fn: GenerativeFunction,
#     465     args: Tuple,
#     466 ):
# --> 467     return trace(addr if isinstance(addr, tuple) else (addr,), gen_fn, args)
#
# File <@beartype(genjax._src.generative_functions.static.trace) at 0x127c63740>:89, in trace(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_4376485712, __beartype_func, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:178, in trace(addr, gen_fn, args)
#     170 """Invoke a generative function, binding its generative semantics with the current
#     171 caller.
#     172
#    (...)
#     175     gen_fn: A generative function invoked as a callee of `StaticGenerativeFunction`.
#     176 """
#     177 addr = Pytree.tree_const(addr)
# --> 178 return initial_style_bind(trace_p)(_abstract_gen_fn_call)(
#     179     addr,
#     180     gen_fn,
#     181     args,
#     182 )
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/forward.py:121, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     119 def wrapped(*args, **kwargs):
#     120     """Runs a function and binds it to a call primitive."""
# --> 121     _jaxpr, (flat_args, in_tree, out_tree) = stage(f)(*args, **kwargs)
#     122     outs = prim.bind(
#     123         *it.chain(_jaxpr.literals, flat_args),
#     124         _jaxpr=_jaxpr.jaxpr,
#    (...)
#     128         **params,
#     129     )
#     130     return tree_util.tree_unflatten(out_tree(), outs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:125, in stage.<locals>.wrapped(*args, **kwargs)
#     123 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#     124 flat_avals = safe_map(get_shaped_aval, flat_args)
# --> 125 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#     126 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/interpreters/staging.py:112, in cached_stage_dynamic(flat_fun, in_avals)
#     110 @lu.cache
#     111 def cached_stage_dynamic(flat_fun, in_avals):
# --> 112     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#     113     typed_jaxpr = jc.ClosedJaxpr(jaxpr, consts)
#     114     return typed_jaxpr
#
#     [... skipping hidden 5 frame]
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/static.py:161, in _abstract_gen_fn_call(_, gen_fn, args)
#     156 def _abstract_gen_fn_call(
#     157     _: Address,
#     158     gen_fn: GenerativeFunction,
#     159     args: Tuple,
#     160 ):
# --> 161     return gen_fn.__abstract_call__(*args)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/distributions/distribution.py:498, in ExactDensity.__abstract_call__(self, *args)
#     496 def __abstract_call__(self, *args):
#     497     key = jax.random.PRNGKey(0)
# --> 498     return self.sample(key, *args)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/distributions/distribution.py:574, in ExactDensityFromCallables.sample(self, key, *args)
#     573 def sample(self, key, *args):
# --> 574     return self.sampler(key, *args)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/core/pytree.py:474, in Closure.__call__(self, *args, **kwargs)
#     473 def __call__(self, *args, **kwargs):
# --> 474     return self.fn(*self.dyn_args, *args, **kwargs)
#
# File ~/repos/genjax-docs/genjax/src/genjax/_src/generative_functions/distributions/distribution.py:503, in ExactDensity.handle_kwargs.<locals>.sample_with_kwargs(self, key, args, kwargs)
#     501 @Pytree.partial(self)
#     502 def sample_with_kwargs(self, key, args, kwargs):
# --> 503     return self.sample(key, *args, **kwargs)
#
# TypeError: ExactDensityFromCallables.sample() got an unexpected keyword argument 'logits'
