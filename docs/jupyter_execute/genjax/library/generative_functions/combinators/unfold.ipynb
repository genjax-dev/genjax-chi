# %%
import jax
import genjax
console = genjax.pretty()

@genjax.gen
def random_walk(prev):
    x = genjax.trace("x", genjax.Normal)(prev, 1.0)
    return x


unfold = genjax.UnfoldCombinator(random_walk, 1000)
init = 0.5
key = jax.random.PRNGKey(314159)
key, tr = jax.jit(genjax.simulate(unfold))(key, (999, init))
console.print(tr)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/mk/btkplz1n40q001dsy957srbh0000gn/T/ipykernel_35784/1737337849.py:14 in <module>    │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/mk/btkplz1n40q001dsy957srbh0000gn/T/ipykernel_35784/1737337849.py'                 │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/traceba │
# │ ck_util.py:162 in reraise_with_filtered_traceback                                                │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/api.py: │
# │ 622 in cache_miss                                                                                │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/dispatc │
# │ h.py:241 in _xla_call_impl_lazy                                                                  │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/linear_util. │
# │ py:303 in memoized_fun                                                                           │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/dispatc │
# │ h.py:357 in _xla_callable_uncached                                                               │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/dispatc │
# │ h.py:348 in sharded_lowering                                                                     │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/profile │
# │ r.py:314 in wrapper                                                                              │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/interpreters │
# │ /pxla.py:2792 in lower_sharding_computation                                                      │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/profile │
# │ r.py:314 in wrapper                                                                              │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/interpreters │
# │ /partial_eval.py:2065 in trace_to_jaxpr_final                                                    │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/interpreters │
# │ /partial_eval.py:1998 in trace_to_subjaxpr_dynamic                                               │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/linear_util. │
# │ py:167 in call_wrapped                                                                           │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/genjax/_src/inte │
# │ rface.py:47 in <lambda>                                                                          │
# │                                                                                                  │
# │   44                                                                                             │
# │   45                                                                                             │
# │   46 def simulate(gen_fn, **kwargs) -> Callable:                                                 │
# │ ❱ 47 │   return lambda *args: gen_fn.simulate(*args, **kwargs)                                   │
# │   48                                                                                             │
# │   49                                                                                             │
# │   50 def importance(gen_fn, **kwargs) -> Callable:                                               │
# │ <@beartype(genjax._src.generative_functions.combinators.unfold.UnfoldCombinator.simulate) at     │
# │ 0x12440aa70>:52 in simulate                                                                      │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/genjax/_src/gene │
# │ rative_functions/combinators/unfold.py:190 in simulate                                           │
# │                                                                                                  │
# │   187 │   │   static_args = args[2:]                                                             │
# │   188 │   │                                                                                      │
# │   189 │   │   # This inserts a host callback check for bounds checking.                          │
# │ ❱ 190 │   │   check = jnp.less(self.max_length, length + 1)                                      │
# │   191 │   │   concrete_cond(                                                                     │
# │   192 │   │   │   check,                                                                         │
# │   193 │   │   │   lambda *args: self._throw_bounds_host_exception(length + 1),                   │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/traceba │
# │ ck_util.py:162 in reraise_with_filtered_traceback                                                │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/api.py: │
# │ 626 in cache_miss                                                                                │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/interpreters │
# │ /partial_eval.py:1739 in process_call                                                            │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/interpreters │
# │ /partial_eval.py:2027 in trace_to_subjaxpr_dynamic2                                              │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/linear_util. │
# │ py:167 in call_wrapped                                                                           │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/numpy/u │
# │ funcs.py:110 in fn                                                                               │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/numpy/u │
# │ til.py:363 in _promote_args                                                                      │
# │                                                                                                  │
# │ /Users/mccoybecker/research/genjax/.nox/docs-build/lib/python3.10/site-packages/jax/_src/numpy/u │
# │ til.py:345 in _check_arraylike                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: less requires ndarray or scalar arguments, got <class
# 'genjax._src.generative_functions.builtin.builtin_gen_fn.BuiltinGenerativeFunction'> at position 0.
