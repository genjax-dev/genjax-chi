# %% [raw]
# ---
# title: Differentiable programming with GenJAX
# date: "December 7, 2022"
# abstract: This notebook describes the gradient interfaces exposed by generative function implementors in GenJAX. It also describes `TrainCombinator`, a generative function combinator which exposes interfaces that make it easy to train learnable parameters with custom optimizers (from e.g. [`optax`](https://optax.readthedocs.io/en/latest/)) using gradients with respect to the log joint density of the model. To illustrate the interfaces, we showcase a MAP optimization implementation, as well as a Metropolis Adjusted Langevin Algorithm (MALA) implementation. We also show how `TrainCombinator` can be used to perform maximum likelihood optimization, as well as variational family optimization.
# callout-appearance: simple
# ---

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
import dataclasses

import genjax
import jax
import jax.numpy as jnp
import jax.tree_util as jtu
import matplotlib.pyplot as plt
import seaborn as sns
from genjax import normal, trace, uniform

sns.set_theme(style="white")

# Pretty printing.
console = genjax.console(width=80)

# Reproducibility.
key = jax.random.PRNGKey(314159)

# %% [markdown]
# The generative function interface exposes functionality which allows usage of generative functions for differentiable programming. These interfaces are designed to work seamlessly with `jax.grad` - allowing (even higher-order) gradient computations which are useful for inference algorithms which require gradients and gradient estimators. In this notebook, we'll describe some of these interfaces - as well as their (current, but not forever) limitations. We'll walk through an implementation of MAP estimation, as well as the Metropolis-adjusted Langevin algorithm (MALA) using these interfaces.

# %% [markdown]
# ## Gradient interfaces

# %% [markdown]
# Because JAX features best-in-class support for higher-order AD, GenJAX exposes interfaces that compose natively with JAX's interfaces for gradients. The primary interface method which provides `jax.grad`-compatible functions from generative functions is an interface called `unzip`.
#
# `unzip` allows a user to provide a key, and a fixed choice map - and it returns a new key and two closures:
#
# * The first closure is a "score" closure which accepts a choice map as the first argument, and arguments which match the non-`PRNGKey` signature types of the generative function. The score closure returns the exact joint score of the generative function. It computes the exact joint score using an interface called `assess`.^[Caveat: `assess` is not required to return the _exact_ joint score, only an estimate. However, if `jax.grad` is used on estimates - the resulting thing is not a correct gradient estimator. See the important callout below!]
# * The second closure is a "retval" closure which accepts a choice map as the first argument, and arguments which match the non-`PRNGKey` signature types of the generative function. The retval closure executes the generative function constrained using the union of the fixed choice map, and the user provided choice map, and returns the return value of the execution. Here, the return value is also provided by invoking the `assess` interface.

# %% [markdown]
# So really, `unzip` is syntactic sugar over another interface called `assess`.

# %% [markdown]
# ### `assess` for exact density evaluation

# %% [markdown]
# `assess` is a generative function interface method which computes log joint density estimates from generative functions. `assess` requires that a user provide a choice map _which completely fills all choices encountered during execution_. Otherwise, it errors.^[And these errors are thrown at JAX trace time, so you'll get an exception before runtime.]
#
# If a generative function also draws from untraced randomness - `assess` computes an estimate whose expectation over the distribution of untraced randomness gives the correct log joint density.
#
# ::: {.callout-important}
#
# ## Correctness of gradient estimators
#
# When used on generative functions which include untraced randomness, naively applying `jax.grad` to the closures returned by interfaces described in this notebook **do not compute** gradient estimators which are unbiased with respect to the true gradients.
#
# Short: don't use these with untraced randomness. We're working on alternatives.
#
# :::

# %% [markdown]
# ## A running example

# %% [markdown]
# Let's consider the following model, which we'll cover in different variations.

# %%
@genjax.Repeat(repeats=100)
@genjax.Static
def sample_x(x_mu, var):
    position = trace("pos", normal)(x_mu, 1.0)
    return position


@genjax.Map(in_axes=(0, None, None))
@genjax.Static
def sample_y(x, a, b):
    position = trace("pos", normal)(a * x + b, 1.0)
    return position


@genjax.Static
def model():
    x_mu = trace("x_mu", uniform)(-3.0, 3.0)
    a = trace("a", uniform)(-4.0, 4.0)
    b = trace("b", uniform)(-3.0, 3.0)
    x = trace("x", sample_x)(x_mu, 1.0)
    y = trace("y", sample_y)(x, a, b)
    return y

# %% [markdown]
# And, most importantly, visualizations.

# %%
def viz(ax, x, y, **kwargs):
    sns.scatterplot(x=x, y=y, ax=ax, **kwargs)


f, axes = plt.subplots(3, 3, figsize=(9, 9), sharex=True, sharey=True, dpi=280)
jitted = jax.jit(model.simulate)
trs = []
for ax in axes.flatten():
    key, tr = jitted(key, ())
    x = tr["x", "pos"]
    y = tr["y", "pos"]
    trs.append(tr)
    viz(ax, x, y, marker=".")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       7 trs = []
#       8 for ax in axes.flatten():
# ----> 9     key, tr = jitted(key, ())
#      10     x = tr["x", "pos"]
#      11     y = tr["y", "pos"]
#
#     [... skipping hidden 12 frame]
#
# File <@beartype(genjax._src.generative_functions.static.static_gen_fn.StaticGenerativeFunction.simulate) at 0x134930720>:53, in simulate(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_object_5175963776, __beartype_object_140291197377808, *args, **kwargs)
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/static/static_gen_fn.py:91, in StaticGenerativeFunction.simulate(self, key, args)
#      82 @typecheck
#      83 def simulate(
#      84     self,
#      85     key: PRNGKey,
#      86     args: Tuple,
#      87 ) -> StaticTrace:
#      88     syntax_sugar_handled = push_trace_overload_stack(
#      89         handler_trace_with_static, self.source
#      90     )
# ---> 91     (args, retval, address_choices, score), cache_state = simulate_transform(
#      92         syntax_sugar_handled
#      93     )(key, args)
#      94     return StaticTrace(
#      95         self,
#      96         args,
#    (...)
#     100         score,
#     101     )
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/static/static_transforms.py:307, in simulate_transform.<locals>.wrapper(key, args)
#     304 @functools.wraps(source_fn)
#     305 def wrapper(key, args):
#     306     stateful_handler = SimulateHandler(key)
# --> 307     retval = forward(source_fn)(stateful_handler, *args)
#     308     (
#     309         address_choices,
#     310         cache_state,
#     311         score,
#     312     ) = stateful_handler.yield_state()
#     313     return (
#     314         args,
#     315         retval,
#     316         address_choices,
#     317         score,
#     318     ), cache_state
#
# File <@beartype(genjax._src.core.interpreters.forward.forward.wrapped) at 0x16b9bd9e0>:31, in wrapped(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_object_140289857879824, *args, **kwargs)
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/forward.py:254, in forward.<locals>.wrapped(stateful_handler, *args)
#     250 @functools.wraps(f)
#     251 @typecheck
#     252 def wrapped(stateful_handler: StatefulHandler, *args):
#     253     interpreter = ForwardInterpreter()
# --> 254     return interpreter.run_interpreter(
#     255         stateful_handler,
#     256         f,
#     257         *args,
#     258     )
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/forward.py:237, in ForwardInterpreter.run_interpreter(self, stateful_handler, fn, *args, **kwargs)
#     234 def _inner(*args):
#     235     return fn(*args, **kwargs)
# --> 237 _closed_jaxpr, (flat_args, _, out_tree) = stage(_inner)(*args)
#     238 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
#     239 flat_out = self._eval_jaxpr_forward(
#     240     stateful_handler,
#     241     _jaxpr,
#     242     consts,
#     243     flat_args,
#     244 )
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/staging.py:76, in stage.<locals>.wrapped(*args, **kwargs)
#      74 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#      75 flat_avals = safe_map(get_shaped_aval, flat_args)
# ---> 76 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#      77 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/staging.py:63, in cached_stage_dynamic(flat_fun, in_avals)
#      61 @lu.cache
#      62 def cached_stage_dynamic(flat_fun, in_avals):
# ---> 63     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#      64     typed_jaxpr = jax_core.ClosedJaxpr(jaxpr, consts)
#      65     return typed_jaxpr
#
#     [... skipping hidden 4 frame]
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/forward.py:235, in ForwardInterpreter.run_interpreter.<locals>._inner(*args)
#     234 def _inner(*args):
# --> 235     return fn(*args, **kwargs)
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/supports_callees.py:52, in push_trace_overload_stack.<locals>.wrapped(*args)
#      50 def wrapped(*args):
#      51     GLOBAL_TRACE_HANDLER_STACK.append(handler)
# ---> 52     ret = fn(*args)
#      53     GLOBAL_TRACE_HANDLER_STACK.pop()
#      54     return ret
#
# Cell In[21], line 20, in model()
#      18 a = trace("a", uniform)(-4.0, 4.0)
#      19 b = trace("b", uniform)(-3.0, 3.0)
# ---> 20 x = trace("x", sample_x)(x_mu, 1.0)
#      21 y = trace("y", sample_y)(x, a, b)
#      22 return y
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/static/static_transforms.py:149, in trace.<locals>.<lambda>(*args)
#     138 """Invoke a generative function, binding its generative semantics with the
#     139 current caller.
#     140
#    (...)
#     146     callable: A callable which wraps the `trace_p` primitive, accepting arguments (`args`) and binding the primitive with them. This raises the primitive to be handled by `StaticGenerativeFunction` transformations.
#     147 """
#     148 assert isinstance(gen_fn, GenerativeFunction)
# --> 149 return lambda *args: _trace(gen_fn, addr, *args)
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/static/static_transforms.py:129, in _trace(gen_fn, addr, *args)
#     127 static_check_address_type(addr)
#     128 addr = tree_map_const(addr)
# --> 129 return initial_style_bind(trace_p)(_abstract_gen_fn_call)(
#     130     gen_fn,
#     131     addr,
#     132     *args,
#     133 )
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/forward.py:123, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     121 def wrapped(*args, **kwargs):
#     122     """Runs a function and binds it to a call primitive."""
# --> 123     _jaxpr, (flat_args, in_tree, out_tree) = stage(f)(*args, **kwargs)
#     124     outs = prim.bind(
#     125         *it.chain(_jaxpr.literals, flat_args),
#     126         _jaxpr=_jaxpr.jaxpr,
#    (...)
#     130         **params,
#     131     )
#     132     return tree_util.tree_unflatten(out_tree(), outs)
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/staging.py:76, in stage.<locals>.wrapped(*args, **kwargs)
#      74 flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)
#      75 flat_avals = safe_map(get_shaped_aval, flat_args)
# ---> 76 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#      77 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/interpreters/staging.py:63, in cached_stage_dynamic(flat_fun, in_avals)
#      61 @lu.cache
#      62 def cached_stage_dynamic(flat_fun, in_avals):
# ---> 63     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#      64     typed_jaxpr = jax_core.ClosedJaxpr(jaxpr, consts)
#      65     return typed_jaxpr
#
#     [... skipping hidden 4 frame]
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/static/static_transforms.py:118, in _abstract_gen_fn_call(gen_fn, _, *args)
#     117 def _abstract_gen_fn_call(gen_fn, _, *args):
# --> 118     return gen_fn.__abstract_call__(*args)
#
# File ~/Work/MIT/genjax/src/genjax/_src/core/datatypes/generative.py:1183, in GenerativeFunction.__abstract_call__(self, *args)
#    1179 def __abstract_call__(self, *args) -> Any:
#    1180     # This should occur only during abstract evaluation,
#    1181     # the fact that the value has type PRNGKey is all that matters.
#    1182     key = jax.random.PRNGKey(0)
# -> 1183     tr = self.simulate(key, args)
#    1184     retval = tr.get_retval()
#    1185     return retval
#
# File <@beartype(genjax._src.generative_functions.combinators.vector.repeat_combinator.RepeatCombinator.simulate) at 0x1349916c0>:53, in simulate(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_object_5175963776, __beartype_object_140291197473760, *args, **kwargs)
#
# File ~/Work/MIT/genjax/src/genjax/_src/generative_functions/combinators/vector/repeat_combinator.py:88, in RepeatCombinator.simulate(self, key, args)
#      83 sub_keys = jax.random.split(key, self.repeats)
#      84 repeated_inner_tr = jax.vmap(
#      85     self.inner.simulate,
#      86     in_axes=(0, None),
#      87 )(sub_keys, args)
# ---> 88 return RepeatTrace(repeated_inner_tr, args)
#
# TypeError: RepeatTrace.__init__() takes 2 positional arguments but 3 were given

# %% [markdown]
# A nice diffuse prior over points.

# %% [markdown]
# ## MAP estimation

# %% [markdown]
# When it comes to looking at the interfaces, a good first step is gradient-based maximum a posteriori probability (MAP) estimation. Let's write this using the lowest level interface `unzip` first:

# %% [markdown]
# Now, often we may have a trace in hand, and we just want the first-order gradient with respect to certain random choices (specified by a `genjax.Selection`). This is a relatively common occurrence - so there's a higher-level API `choice_grad` which gives us exactly this thing.^[It's not compositional with `jax.grad` - but if we need that power, we can just drop back down to use `unzip`.] Here's `MapUpdate` using `choice_grad`.

# %%
@dataclasses.dataclass
class MapUpdate(genjax.Pytree):
    selection: genjax.Selection
    tau: genjax.typing.FloatArray

    def flatten(self):
        return (self.tau,), (self.selection,)

    def apply(self, key, trace):
        args = trace.get_args()
        gen_fn = trace.get_gen_fn()
        key, forward_gradient_trie = gen_fn.choice_grad(key, trace, self.selection)
        forward_values = self.selection.filter(trace)
        forward_values = forward_values.strip()
        forward_values = jtu.tree_map(
            lambda v1, v2: v1 + self.tau * v2,
            forward_values,
            forward_gradient_trie,
        )
        argdiffs = tuple(map(genjax.Diff.no_change, args))
        key, (_, _, new_trace, _) = gen_fn.update(key, trace, forward_values, argdiffs)
        return key, (new_trace, True)

    def __call__(self, key, trace):
        return self.apply(key, trace)

# %% [markdown]
# Simple, concise - works with any generative function whose choices specified by `MapUpdate.selection` support gradients on the joint logpdf.
#
# From the `Pytree` interface, any instance of `MapUpdate` has a static `selection`, and a `tau` (which determines the gradient step size) which can be dynamic.^[If this is your first time seeing the `Pytree` interface, note that it's defined by the `flatten` interface - which allows us to specify runtime vs. trace time data in `Pytree` structures.]
#
# Because `MapUpdate` is a `Pytree`, in inference code, we'd just construct `MapUpdate` before calling it - and we can do this on either side of the JAX API boundary.^[E.g. outside of a `jax.jit` transform, inside - it's all okay.]

# %%
update = MapUpdate(genjax.select(["x_mu", "a", "b"]), 1e-4)
update
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# MapUpdate
# ├── selection
# │   └── BuiltinSelection
# │       └── trie
# │           └── Trie
# │               ├── :x_mu
# │               │   └── AllSelection
# │               ├── :a
# │               │   └── AllSelection
# │               └── :b
# │                   └── AllSelection
# └── tau
#     └── (const) 0.0001

# %% [markdown]
# Let's take a sampled piece of data, extract the `("x", "pos")` and `("y", "pos")` addresses, and then use MAP optimization to estimate the mode of the posterior.

# %%
tr = trs[2]
selection = genjax.select(["x", "y"])
chm = selection.filter(tr.strip())
chm
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# BuiltinChoiceMap
# └── trie
#     └── Trie
#         ├── :x
#         │   └── VectorChoiceMap
#         │       ├── indices
#         │       │   └──  i32[100]
#         │       └── inner
#         │           └── BuiltinChoiceMap
#         │               └── trie
#         │                   └── Trie
#         │                       └── :pos
#         │                           └── ValueChoiceMap
#         │                               └── value
#         │                                   └──  f32[100]
#         └── :y
#             └── VectorChoiceMap
#                 ├── indices
#                 │   └──  i32[100]
#                 └── inner
#                     └── BuiltinChoiceMap
#                         └── trie
#                             └── Trie
#                                 └── :pos
#                                     └── ValueChoiceMap
#                                         └── value
#                                             └──  f32[100]

# %%
x = chm["x", "pos"]
y = chm["y", "pos"]
fig_data, ax_data = plt.subplots(figsize=(3, 3), dpi=140)
viz(ax_data, x, y, marker=".")

# %% [markdown]
# If we apply `MapUpdate`, we take a single optimization step:

# %%
key, (_, tr) = jax.jit(model.importance)(key, chm, ())
key, (tr, _) = update(key, tr)

# %% [markdown]
# We can use scan to apply `MapUpdate` repeatedly.

# %%
def chain(key, tr):
    def _inner(carry, _):
        key, tr = carry
        key, (tr, _) = update(key, tr)
        return (key, tr), ()

    (key, tr), _ = jax.lax.scan(_inner, (key, tr), None, length=2000)
    return key, tr

# %%
jitted = jax.jit(chain)
key, tr = jitted(key, tr)

# %% [markdown]
# Now, we can plot the polynomial described by `"a"` and `"b"`, with evaluation points generated around the estimated `"x_mu"`.

# %%
def polynomial_at_x(x, coefficients):
    basis_values = jnp.array([1.0, x])
    polynomial_value = jnp.sum(coefficients * basis_values)
    return polynomial_value


jitted = jax.jit(jax.vmap(polynomial_at_x, in_axes=(0, None)))


def plot_polynomial_values(ax, x, coefficients, **kwargs):
    v = jitted(x, coefficients)
    ax.scatter(x, v, **kwargs)


a = tr["a"]
b = tr["b"]
x_mu = tr["x_mu"]
key, sub_key = jax.random.split(key)
evaluation_points = x_mu + jax.random.normal(sub_key, shape=(1000,))
coefficients = jnp.array([b, a])
plot_polynomial_values(
    ax_data,
    evaluation_points,
    coefficients,
    marker=".",
    color="gold",
    alpha=0.05,
)
fig_data
