# %%
import os

import numpy as np
import torch
from pyro.contrib.examples.util import MNIST
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

assert pyro.__version__.startswith('1.8.6')
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
smoke_test = 'CI' in os.environ

# for loading and batching MNIST dataset
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = MNIST(root=root, train=True, transform=trans,
                      download=download)
    test_set = MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 784)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = self.sigmoid(self.fc21(hidden))
        return loc_img

class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(784, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 784)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale

# %%
# define the model p(x|z)p(z)
def model(self, x):
    # register PyTorch module `decoder` with Pyro
    pyro.module("decoder", self.decoder)
    with pyro.plate("data", x.shape[0]):
        # setup hyperparameters for prior p(z)
        z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
        z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
        # sample from prior (value will be sampled by guide when computing the ELBO)
        z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
        # decode the latent code z
        loc_img = self.decoder(z)
        # score against actual images
        pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

# define the guide (i.e. variational distribution) q(z|x)
def guide(self, x):
    # register PyTorch module `encoder` with Pyro
    pyro.module("encoder", self.encoder)
    with pyro.plate("data", x.shape[0]):
        # use the encoder to get the parameters used to define q(z|x)
        z_loc, z_scale = self.encoder(x)
        # sample the latent code z
        pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder(z)
            # score against actual images
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %% [markdown]
# ## Inference

# %%
def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
# Run options
LEARNING_RATE = 1.0e-3
USE_CUDA = True

# Run only for a single iteration for testing
NUM_EPOCHS = 1 if smoke_test else 100
TEST_FREQUENCY = 5

train_loader, test_loader = setup_data_loaders(batch_size=256, use_cuda=USE_CUDA)

# clear param store
pyro.clear_param_store()

# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# [epoch 000]  average training loss: 191.0568
# [epoch 000] average test loss: 156.2251
# [epoch 001]  average training loss: 146.5941
# [epoch 002]  average training loss: 132.9172
# [epoch 003]  average training loss: 124.5500
# [epoch 004]  average training loss: 119.4308
# [epoch 005]  average training loss: 116.1514
# [epoch 005] average test loss: 114.0645
# [epoch 006]  average training loss: 113.8621
# [epoch 007]  average training loss: 112.2470
# [epoch 008]  average training loss: 110.9977
# [epoch 009]  average training loss: 110.0224
# [epoch 010]  average training loss: 109.2843
# [epoch 010] average test loss: 108.6999
# [epoch 011]  average training loss: 108.5828
# [epoch 012]  average training loss: 108.0402
# [epoch 013]  average training loss: 107.5707
# [epoch 014]  average training loss: 107.1392
# [epoch 015]  average training loss: 106.7966
# [epoch 015] average test loss: 106.0218
# [epoch 016]  average training loss: 106.4967
# [epoch 017]  average training loss: 106.1941
# [epoch 018]  average training loss: 105.9709
# [epoch 019]  average training loss: 105.7162
# [epoch 020]  average training loss: 105.4948
# [epoch 020] average test loss: 104.8675
# [epoch 021]  average training loss: 105.3222
# [epoch 022]  average training loss: 105.1752
# [epoch 023]  average training loss: 105.0183
# [epoch 024]  average training loss: 104.8517
# [epoch 025]  average training loss: 104.7319
# [epoch 025] average test loss: 104.5921
# [epoch 026]  average training loss: 104.6312
# [epoch 027]  average training loss: 104.4506
# [epoch 028]  average training loss: 104.3347
# [epoch 029]  average training loss: 104.2053
# [epoch 030]  average training loss: 104.1654
# [epoch 030] average test loss: 103.8740
# [epoch 031]  average training loss: 104.0577
# [epoch 032]  average training loss: 103.9348
# [epoch 033]  average training loss: 103.8883
# [epoch 034]  average training loss: 103.7879
# [epoch 035]  average training loss: 103.6870
# [epoch 035] average test loss: 103.5715
# [epoch 036]  average training loss: 103.6462
# [epoch 037]  average training loss: 103.5322
# [epoch 038]  average training loss: 103.4579
# [epoch 039]  average training loss: 103.4057
# [epoch 040]  average training loss: 103.3820
# [epoch 040] average test loss: 103.1802
# [epoch 041]  average training loss: 103.2845
# [epoch 042]  average training loss: 103.1870
# [epoch 043]  average training loss: 103.1634
# [epoch 044]  average training loss: 103.1312
# [epoch 045]  average training loss: 103.0451
# [epoch 045] average test loss: 103.0984
# [epoch 046]  average training loss: 103.0125
# [epoch 047]  average training loss: 102.9625
# [epoch 048]  average training loss: 102.8969
# [epoch 049]  average training loss: 102.8685
# [epoch 050]  average training loss: 102.8174
# [epoch 050] average test loss: 102.9056
# [epoch 051]  average training loss: 102.7367
# [epoch 052]  average training loss: 102.7462
# [epoch 053]  average training loss: 102.6278
# [epoch 054]  average training loss: 102.6077
# [epoch 055]  average training loss: 102.5941
# [epoch 055] average test loss: 102.7764
# [epoch 056]  average training loss: 102.5337
# [epoch 057]  average training loss: 102.5022
# [epoch 058]  average training loss: 102.4570
# [epoch 059]  average training loss: 102.4330
# [epoch 060]  average training loss: 102.4027
# [epoch 060] average test loss: 102.5254
# [epoch 061]  average training loss: 102.3545
# [epoch 062]  average training loss: 102.2910
# [epoch 063]  average training loss: 102.2663
# [epoch 064]  average training loss: 102.2183
# [epoch 065]  average training loss: 102.2129
# [epoch 065] average test loss: 102.4154
# [epoch 066]  average training loss: 102.2006
# [epoch 067]  average training loss: 102.1346
# [epoch 068]  average training loss: 102.1141
# [epoch 069]  average training loss: 102.0611
# [epoch 070]  average training loss: 102.0478
# [epoch 070] average test loss: 102.1119
# [epoch 071]  average training loss: 101.9749
# [epoch 072]  average training loss: 101.9696
# [epoch 073]  average training loss: 101.9684
# [epoch 074]  average training loss: 101.9292
# [epoch 075]  average training loss: 101.8763
# [epoch 075] average test loss: 101.9940
# [epoch 076]  average training loss: 101.8676
# [epoch 077]  average training loss: 101.8138
# [epoch 078]  average training loss: 101.8108
# [epoch 079]  average training loss: 101.7836
# [epoch 080]  average training loss: 101.7567
# [epoch 080] average test loss: 101.9961
# [epoch 081]  average training loss: 101.7256
# [epoch 082]  average training loss: 101.6961
# [epoch 083]  average training loss: 101.6726
# [epoch 084]  average training loss: 101.6448
# [epoch 085]  average training loss: 101.6000
# [epoch 085] average test loss: 101.9701
# [epoch 086]  average training loss: 101.5920
# [epoch 087]  average training loss: 101.5466
# [epoch 088]  average training loss: 101.5297
# [epoch 089]  average training loss: 101.4811
# [epoch 090]  average training loss: 101.4788
# [epoch 090] average test loss: 101.6813
# [epoch 091]  average training loss: 101.4273
# [epoch 092]  average training loss: 101.4085
# [epoch 093]  average training loss: 101.4442
# [epoch 094]  average training loss: 101.3790
# [epoch 095]  average training loss: 101.3493
# [epoch 095] average test loss: 101.6035
# [epoch 096]  average training loss: 101.3375
# [epoch 097]  average training loss: 101.2997
# [epoch 098]  average training loss: 101.2758
# [epoch 099]  average training loss: 101.2566
