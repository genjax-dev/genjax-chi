# %%
import argparse
import inspect
import os
import time

import matplotlib.pyplot as plt

import jax
from jax import jit, lax, random
from jax.example_libraries import stax
import jax.numpy as jnp
import jax.tree_util as jtu
from jax.random import PRNGKey

import numpyro
from numpyro import optim
from numpyro.examples.datasets import MNIST, load_dataset
import adevjax
import genjax
from dataclasses import dataclass
from genjax import dippl
from genjax import gensp
from genjax import select, dirac

console = genjax.pretty(suppress=[], max_frames=50)


RESULTS_DIR = os.path.abspath(
    os.path.join(os.path.dirname(inspect.getfile(lambda: None)), ".results")
)
os.makedirs(RESULTS_DIR, exist_ok=True)


def encoder(hidden_dim, z_dim):
    return stax.serial(
        stax.Dense(hidden_dim, W_init=stax.randn()),
        stax.Softplus,
        stax.FanOut(2),
        stax.parallel(
            stax.Dense(z_dim, W_init=stax.randn()),
            stax.serial(stax.Dense(z_dim, W_init=stax.randn()), stax.Exp),
        ),
    )


def decoder(hidden_dim, out_dim):
    return stax.serial(
        stax.Dense(hidden_dim, W_init=stax.randn()),
        stax.Softplus,
        stax.Dense(out_dim, W_init=stax.randn()),
        stax.Sigmoid,
    )


# Define our gradient estimator using our loss language.
def svi_update(
    model,
    guide,
    optimizer,
):
    def _inner(key, encoder_params, decoder_params, data):
        v_chm = genjax.value_choice_map(
            genjax.choice_map({"image": data.reshape((28 * 28,))})
        )

        @dippl.loss
        def vae_loss(encoder_params, decoder_params):
            v = dippl.upper(guide)(encoder_params, v_chm)
            merged = gensp.merge(v, v_chm)
            dippl.lower(model)(merged, decoder_params)

        loss, (
            encoder_params_grad,
            decoder_params_grad,
        ) = vae_loss.value_and_grad_estimate(key, (encoder_params, decoder_params))
        return (encoder_params_grad, decoder_params_grad), loss

    def batch_update(svi_state, batch):
        (key, optimizer_state) = svi_state
        encoder_params, decoder_params = optimizer.get_params(optimizer_state)
        key, sub_key = jax.random.split(key)
        sub_keys = jax.random.split(sub_key, len(batch))
        (encoder_grads, decoder_grads), loss = jax.vmap(
            _inner, in_axes=(0, None, None, 0)
        )(sub_keys, encoder_params, decoder_params, batch)
        encoder_grads, decoder_grads = jtu.tree_map(
            jnp.mean, (encoder_grads, decoder_grads)
        )
        optimizer_state = optimizer.update(
            (encoder_grads, decoder_grads), optimizer_state
        )
        return (key, optimizer_state), loss

    return batch_update


@jit
def binarize(rng_key, batch):
    return random.bernoulli(rng_key, batch).astype(batch.dtype)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
hidden_dim = 10
z_dim = 100
learning_rate = 1.0e-3
batch_size = 64

encoder_nn_init, encoder_nn_apply = encoder(hidden_dim, z_dim)
decoder_nn_init, decoder_nn_apply = decoder(hidden_dim, 28 * 28)

# Model + guide close over the neural net apply functions.
@genjax.gen
def decoder_model(decoder_params):
    latent = dippl.mv_normal_diag_reparam(jnp.zeros(z_dim), jnp.ones(z_dim)) @ "latent"
    image = decoder_nn_apply(decoder_params, latent)
    noisy_image = dippl.mv_normal_diag_reparam(image, jnp.ones(784)) @ "image"


@genjax.gen
def encoder_model(encoder_params, chm):
    image = chm.get_leaf_value()["image"]
    μ, Σ_scale = encoder_nn_apply(encoder_params, image)
    x = dippl.mv_normal_diag_reparam(μ, Σ_scale) @ "latent"


model = gensp.choice_map_distribution(decoder_model, select("latent", "image"), None)
guide = gensp.choice_map_distribution(encoder_model, select("latent"), None)

adam = optim.Adam(learning_rate)
svi_updater = svi_update(model, guide, adam)
rng_key = PRNGKey(0)
train_init, train_fetch = load_dataset(MNIST, batch_size=batch_size, split="train")
num_train, train_idx = train_init()
rng_key, rng_key_binarize, rng_key_init = random.split(rng_key, 3)
encoder_init_key, decoder_init_key = random.split(rng_key_init)
_, encoder_params = encoder_nn_init(encoder_init_key, (784,))
_, decoder_params = decoder_nn_init(decoder_init_key, (z_dim,))
sample_batch = binarize(rng_key_binarize, train_fetch(0, train_idx)[0])
num_train, train_idx = train_init()


@jit
def epoch_train(svi_state, rng_key, train_idx):
    def body_fn(i, val):
        svi_state = val
        rng_key_binarize = random.fold_in(rng_key, i)
        batch = binarize(rng_key_binarize, train_fetch(i, train_idx)[0])
        svi_state, loss = svi_updater(svi_state, batch)
        return svi_state

    return lax.fori_loop(0, num_train, body_fn, svi_state)


key = random.PRNGKey(314159)
optimizer_state = adam.init((encoder_params, decoder_params))
svi_state = (key, optimizer_state)
svi_state = epoch_train(svi_state, key, train_idx)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:55                                                                                   │
# │                                                                                                  │
# │   52 key = random.PRNGKey(314159)                                                                │
# │   53 optimizer_state = adam.init((encoder_params, decoder_params))                               │
# │   54 svi_state = (key, optimizer_state)                                                          │
# │ ❱ 55 svi_state = epoch_train(svi_state, key, train_idx)                                          │
# │   56                                                                                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/traceback_util.py:177   │
# │ in reraise_with_filtered_traceback                                                               │
# │                                                                                                  │
# │   174   def reraise_with_filtered_traceback(*args, **kwargs):                                    │
# │   175 │   __tracebackhide__ = True                                                               │
# │   176 │   try:                                                                                   │
# │ ❱ 177 │     return fun(*args, **kwargs)                                                          │
# │   178 │   except Exception as e:                                                                 │
# │   179 │     mode = _filtering_mode()                                                             │
# │   180 │     if _is_under_reraiser(e) or mode == "off":                                           │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/pjit.py:255 in          │
# │ cache_miss                                                                                       │
# │                                                                                                  │
# │    252                                                                                           │
# │    253   @api_boundary                                                                           │
# │    254   def cache_miss(*args, **kwargs):                                                        │
# │ ❱  255 │   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(                     │
# │    256 │   │   fun, infer_params_fn, *args, **kwargs)                                            │
# │    257 │   executable = _read_most_recent_pjit_call_executable(jaxpr)                            │
# │    258 │   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)         │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/pjit.py:161 in          │
# │ _python_pjit_helper                                                                              │
# │                                                                                                  │
# │    158                                                                                           │
# │    159                                                                                           │
# │    160 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):                           │
# │ ❱  161   args_flat, _, params, in_tree, out_tree, _ = infer_params_fn(                           │
# │    162 │     *args, **kwargs)                                                                    │
# │    163   for arg in args_flat:                                                                   │
# │    164 │   dispatch.check_arg(arg)                                                               │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/api.py:325 in           │
# │ infer_params                                                                                     │
# │                                                                                                  │
# │    322 │   │   donate_argnames=donate_argnames, device=device, backend=backend,                  │
# │    323 │   │   keep_unused=keep_unused, inline=inline, resource_env=None,                        │
# │    324 │   │   abstracted_axes=abstracted_axes)                                                  │
# │ ❱  325 │   return pjit.common_infer_params(pjit_info_args, *args, **kwargs)                      │
# │    326                                                                                           │
# │    327   has_explicit_sharding = pjit._pjit_explicit_sharding(                                   │
# │    328 │     in_shardings, out_shardings, device, backend)                                       │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/pjit.py:485 in          │
# │ common_infer_params                                                                              │
# │                                                                                                  │
# │    482 │     hashable_pytree(in_shardings), in_avals, in_tree, resource_env, dbg,                │
# │    483 │     device_or_backend_set)                                                              │
# │    484                                                                                           │
# │ ❱  485   jaxpr, consts, canonicalized_out_shardings_flat = _pjit_jaxpr(                          │
# │    486 │     flat_fun, hashable_pytree(out_shardings), in_type, dbg,                             │
# │    487 │     device_or_backend_set, HashableFunction(out_tree, closure=()),                      │
# │    488 │     HashableFunction(res_paths, closure=()))                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/pjit.py:962 in          │
# │ _pjit_jaxpr                                                                                      │
# │                                                                                                  │
# │    959                                                                                           │
# │    960 def _pjit_jaxpr(fun, out_shardings_thunk, in_type, debug_info,                            │
# │    961 │   │   │   │   device_or_backend_set, out_tree, result_paths):                           │
# │ ❱  962   jaxpr, final_consts, out_type = _create_pjit_jaxpr(                                     │
# │    963 │     fun, in_type, debug_info, result_paths)                                             │
# │    964   canonicalized_out_shardings_flat = _check_and_canonicalize_out_shardings(               │
# │    965 │     out_shardings_thunk, out_tree, tuple(out_type), jaxpr.jaxpr.debug_info,             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/linear_util.py:348 in   │
# │ memoized_fun                                                                                     │
# │                                                                                                  │
# │   345 │     ans, stores = result                                                                 │
# │   346 │     fun.populate_stores(stores)                                                          │
# │   347 │   else:                                                                                  │
# │ ❱ 348 │     ans = call(fun, *args)                                                               │
# │   349 │     cache[key] = (ans, fun.stores)                                                       │
# │   350 │                                                                                          │
# │   351 │   return ans                                                                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/pjit.py:915 in          │
# │ _create_pjit_jaxpr                                                                               │
# │                                                                                                  │
# │    912 │     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(                       │
# │    913 │   │     lu.annotate(fun, in_type), debug_info=pe_debug)                                 │
# │    914 │   else:                                                                                 │
# │ ❱  915 │     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(                        │
# │    916 │   │     fun, in_type, debug_info=pe_debug)                                              │
# │    917                                                                                           │
# │    918   if not config.jax_dynamic_shapes:                                                       │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/profiler.py:314 in      │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   311   @wraps(func)                                                                             │
# │   312   def wrapper(*args, **kwargs):                                                            │
# │   313 │   with TraceAnnotation(name, **decorator_kwargs):                                        │
# │ ❱ 314 │     return func(*args, **kwargs)                                                         │
# │   315 │   return wrapper                                                                         │
# │   316   return wrapper                                                                           │
# │   317                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/interpreters/partial_ev │
# │ al.py:2203 in trace_to_jaxpr_dynamic                                                             │
# │                                                                                                  │
# │   2200 ) -> tuple[Jaxpr, list[AbstractValue], list[Any]]:                                        │
# │   2201   with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore            │
# │   2202 │   main.jaxpr_stack = ()  # type: ignore                                                 │
# │ ❱ 2203 │   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(                                 │
# │   2204 │     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)                │
# │   2205 │   del main, fun                                                                         │
# │   2206   return jaxpr, out_avals, consts                                                         │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/interpreters/partial_ev │
# │ al.py:2225 in trace_to_subjaxpr_dynamic                                                          │
# │                                                                                                  │
# │   2222 │   trace = DynamicJaxprTrace(main, core.cur_sublevel())                                  │
# │   2223 │   in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)                          │
# │   2224 │   in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]                 │
# │ ❱ 2225 │   ans = fun.call_wrapped(*in_tracers_)                                                  │
# │   2226 │   out_tracers = map(trace.full_raise, ans)                                              │
# │   2227 │   jaxpr, consts = frame.to_jaxpr(out_tracers)                                           │
# │   2228 │   del fun, main, trace, frame, in_tracers, out_tracers, ans                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/linear_util.py:190 in   │
# │ call_wrapped                                                                                     │
# │                                                                                                  │
# │   187 │   gen = gen_static_args = out_store = None                                               │
# │   188 │                                                                                          │
# │   189 │   try:                                                                                   │
# │ ❱ 190 │     ans = self.f(*args, **dict(self.params, **kwargs))                                   │
# │   191 │   except:                                                                                │
# │   192 │     # Some transformations yield from inside context managers, so we have to             │
# │   193 │     # interrupt them before reraising the exception. Otherwise they will only            │
# │                                                                                                  │
# │ in epoch_train:50                                                                                │
# │                                                                                                  │
# │   47 │   │   svi_state, loss = svi_updater(svi_state, batch)                                     │
# │   48 │   │   return svi_state                                                                    │
# │   49 │                                                                                           │
# │ ❱ 50 │   return lax.fori_loop(0, num_train, body_fn, svi_state)                                  │
# │   51                                                                                             │
# │   52 key = random.PRNGKey(314159)                                                                │
# │   53 optimizer_state = adam.init((encoder_params, decoder_params))                               │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/traceback_util.py:177   │
# │ in reraise_with_filtered_traceback                                                               │
# │                                                                                                  │
# │   174   def reraise_with_filtered_traceback(*args, **kwargs):                                    │
# │   175 │   __tracebackhide__ = True                                                               │
# │   176 │   try:                                                                                   │
# │ ❱ 177 │     return fun(*args, **kwargs)                                                          │
# │   178 │   except Exception as e:                                                                 │
# │   179 │     mode = _filtering_mode()                                                             │
# │   180 │     if _is_under_reraiser(e) or mode == "off":                                           │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops. │
# │ py:1938 in fori_loop                                                                             │
# │                                                                                                  │
# │   1935 │     # non-jit implementation of scan does not support length=0                          │
# │   1936 │     return init_val                                                                     │
# │   1937 │                                                                                         │
# │ ❱ 1938 │   (_, result), _ = scan(_fori_scan_body_fun(body_fun), (lower_, init_val),              │
# │   1939 │   │   │   │   │   │     None, length=upper_ - lower_)                                   │
# │   1940 │   return result                                                                         │
# │   1941                                                                                           │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/traceback_util.py:177   │
# │ in reraise_with_filtered_traceback                                                               │
# │                                                                                                  │
# │   174   def reraise_with_filtered_traceback(*args, **kwargs):                                    │
# │   175 │   __tracebackhide__ = True                                                               │
# │   176 │   try:                                                                                   │
# │ ❱ 177 │     return fun(*args, **kwargs)                                                          │
# │   178 │   except Exception as e:                                                                 │
# │   179 │     mode = _filtering_mode()                                                             │
# │   180 │     if _is_under_reraiser(e) or mode == "off":                                           │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops. │
# │ py:253 in scan                                                                                   │
# │                                                                                                  │
# │    250   # may not match the output despite being compatible by virtue of their weak type.       │
# │    251   # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if     │
# │    252   # necessary, a second time with modified init values.                                   │
# │ ❱  253   init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)         │
# │    254   new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_aval  │
# │    255   if changed:                                                                             │
# │    256 │   init = tree_unflatten(init_tree, new_init_flat)                                       │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops. │
# │ py:239 in _create_jaxpr                                                                          │
# │                                                                                                  │
# │    236 │   in_flat, in_tree = tree_flatten((init, xs))                                           │
# │    237 │                                                                                         │
# │    238 │   carry_avals = tuple(_map(_abstractify, init_flat))                                    │
# │ ❱  239 │   jaxpr, consts, out_tree = _initial_style_jaxpr(                                       │
# │    240 │   │   f, in_tree, (*carry_avals, *x_avals), "scan")                                     │
# │    241 │   out_tree_children = out_tree.children()                                               │
# │    242 │   if len(out_tree_children) != 2:                                                       │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/lax/control_flow/common │
# │ .py:65 in _initial_style_jaxpr                                                                   │
# │                                                                                                  │
# │    62 @weakref_lru_cache                                                                         │
# │    63 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,                                 │
# │    64 │   │   │   │   │   │    primitive_name: Optional[str] = None):                            │
# │ ❱  65   jaxpr, consts, out_tree = _initial_style_open_jaxpr(                                     │
# │    66 │     fun, in_tree, in_avals, primitive_name)                                              │
# │    67   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())                   │
# │    68   return closed_jaxpr, consts, out_tree                                                    │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/lax/control_flow/common │
# │ .py:59 in _initial_style_open_jaxpr                                                              │
# │                                                                                                  │
# │    56   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)                 │
# │    57   debug = pe.debug_info(fun, in_tree, out_tree, False,                                     │
# │    58 │   │   │   │   │   │   primitive_name or "<unknown>")                                     │
# │ ❱  59   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals, debug)               │
# │    60   return jaxpr, consts, out_tree()                                                         │
# │    61                                                                                            │
# │    62 @weakref_lru_cache                                                                         │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/profiler.py:314 in      │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   311   @wraps(func)                                                                             │
# │   312   def wrapper(*args, **kwargs):                                                            │
# │   313 │   with TraceAnnotation(name, **decorator_kwargs):                                        │
# │ ❱ 314 │     return func(*args, **kwargs)                                                         │
# │   315 │   return wrapper                                                                         │
# │   316   return wrapper                                                                           │
# │   317                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/interpreters/partial_ev │
# │ al.py:2203 in trace_to_jaxpr_dynamic                                                             │
# │                                                                                                  │
# │   2200 ) -> tuple[Jaxpr, list[AbstractValue], list[Any]]:                                        │
# │   2201   with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore            │
# │   2202 │   main.jaxpr_stack = ()  # type: ignore                                                 │
# │ ❱ 2203 │   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(                                 │
# │   2204 │     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)                │
# │   2205 │   del main, fun                                                                         │
# │   2206   return jaxpr, out_avals, consts                                                         │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/interpreters/partial_ev │
# │ al.py:2225 in trace_to_subjaxpr_dynamic                                                          │
# │                                                                                                  │
# │   2222 │   trace = DynamicJaxprTrace(main, core.cur_sublevel())                                  │
# │   2223 │   in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)                          │
# │   2224 │   in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]                 │
# │ ❱ 2225 │   ans = fun.call_wrapped(*in_tracers_)                                                  │
# │   2226 │   out_tracers = map(trace.full_raise, ans)                                              │
# │   2227 │   jaxpr, consts = frame.to_jaxpr(out_tracers)                                           │
# │   2228 │   del fun, main, trace, frame, in_tracers, out_tracers, ans                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/linear_util.py:190 in   │
# │ call_wrapped                                                                                     │
# │                                                                                                  │
# │   187 │   gen = gen_static_args = out_store = None                                               │
# │   188 │                                                                                          │
# │   189 │   try:                                                                                   │
# │ ❱ 190 │     ans = self.f(*args, **dict(self.params, **kwargs))                                   │
# │   191 │   except:                                                                                │
# │   192 │     # Some transformations yield from inside context managers, so we have to             │
# │   193 │     # interrupt them before reraising the exception. Otherwise they will only            │
# │                                                                                                  │
# │                                     ... 65 frames hidden ...                                     │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/builtin/builtin_transforms.py │
# │ :275 in wrapper                                                                                  │
# │                                                                                                  │
# │   272 │   @functools.wraps(source_fn)                                                            │
# │   273 │   def wrapper(key, constraints, args):                                                   │
# │   274 │   │   ctx = ImportanceContext.new(key, constraints)                                      │
# │ ❱ 275 │   │   retvals, statefuls = context.transform(source_fn, ctx)(*args, **kwargs)            │
# │   276 │   │   score, weight, choices, cache = statefuls                                          │
# │   277 │   │   return (weight, (source_fn, args, retvals, choices, score)), cache                 │
# │   278                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/context.py:448 in wrapped        │
# │                                                                                                  │
# │   445 │   │   │   flat_args, in_tree = jtu.tree_flatten(args)                                    │
# │   446 │   │   │   flat_fun, out_tree = api_util.flatten_fun_nokwargs(fun, in_tree)               │
# │   447 │   │   │   flat_fun = _transform(flat_fun, trace_type, main, ctx)                         │
# │ ❱ 448 │   │   │   out_flat, ctx_statefuls = flat_fun.call_wrapped(flat_args)                     │
# │   449 │   │   │   del main                                                                       │
# │   450 │   │   return jtu.tree_unflatten(out_tree(), out_flat), ctx_statefuls                     │
# │   451                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/linear_util.py:190 in   │
# │ call_wrapped                                                                                     │
# │                                                                                                  │
# │   187 │   gen = gen_static_args = out_store = None                                               │
# │   188 │                                                                                          │
# │   189 │   try:                                                                                   │
# │ ❱ 190 │     ans = self.f(*args, **dict(self.params, **kwargs))                                   │
# │   191 │   except:                                                                                │
# │   192 │     # Some transformations yield from inside context managers, so we have to             │
# │   193 │     # interrupt them before reraising the exception. Otherwise they will only            │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/context.py:438 in                │
# │ _run_interpreter                                                                                 │
# │                                                                                                  │
# │   435 │   # Runs the interpreter.                                                                │
# │   436 │   def _run_interpreter(main, *args, **kwargs):                                           │
# │   437 │   │   with Fwd.new() as interpreter:                                                     │
# │ ❱ 438 │   │   │   return interpreter.run_interpreter(trace_type, main, f, *args, **kwargs)       │
# │   439 │                                                                                          │
# │   440 │   # Propagates tracer values through running the interpreter.                            │
# │   441 │   @functools.wraps(f)                                                                    │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/context.py:307 in                │
# │ run_interpreter                                                                                  │
# │                                                                                                  │
# │   304 │   def run_interpreter(self, trace_type, main, fn, *args, **kwargs):                      │
# │   305 │   │   closed_jaxpr, (flat_args, _, out_tree) = staging.stage(fn)(*args, **kwargs)        │
# │   306 │   │   jaxpr, consts = closed_jaxpr.jaxpr, closed_jaxpr.literals                          │
# │ ❱ 307 │   │   flat_out = self._eval_jaxpr(trace_type, main, jaxpr, consts, flat_args)            │
# │   308 │   │   out = jtu.tree_unflatten(out_tree, flat_out)                                       │
# │   309 │   │   return out                                                                         │
# │   310                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/context.py:298 in _eval_jaxpr    │
# │                                                                                                  │
# │   295 │   │   jax_util.safe_map(env.write, jaxpr.invars, args)                                   │
# │   296 │   │   for eqn in jaxpr.eqns:                                                             │
# │   297 │   │   │   invals = jax_util.safe_map(env.read, eqn.invars)                               │
# │ ❱ 298 │   │   │   outvals = eqn.primitive.bind_with_trace(trace, invals, eqn.params)             │
# │   299 │   │   │   if not eqn.primitive.multiple_results:                                         │
# │   300 │   │   │   │   outvals = [outvals]                                                        │
# │   301 │   │   │   jax_util.safe_map(env.write, eqn.outvars, outvals)                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/core.py:389 in          │
# │ bind_with_trace                                                                                  │
# │                                                                                                  │
# │    386 │   return self.bind_with_trace(find_top_trace(args), args, params)                       │
# │    387                                                                                           │
# │    388   def bind_with_trace(self, trace, args, params):                                         │
# │ ❱  389 │   out = trace.process_primitive(self, map(trace.full_raise, args), params)              │
# │    390 │   return map(full_lower, out) if self.multiple_results else full_lower(out)             │
# │    391                                                                                           │
# │    392   def def_impl(self, impl):                                                               │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/context.py:81 in                 │
# │ process_primitive                                                                                │
# │                                                                                                  │
# │    78 │   │   context = staging.get_dynamic_context(self)                                        │
# │    79 │   │   custom_rule = context.get_custom_rule(primitive)                                   │
# │    80 │   │   if custom_rule:                                                                    │
# │ ❱  81 │   │   │   return custom_rule(self, *tracers, **params)                                   │
# │    82 │   │   return self.default_process_primitive(primitive, tracers, params)                  │
# │    83 │                                                                                          │
# │    84 │   def default_process_primitive(                                                         │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/builtin/builtin_transforms.py │
# │ :254 in handle_trace                                                                             │
# │                                                                                                  │
# │   251 │   │   sub_map = self.constraints.get_subtree(addr)                                       │
# │   252 │   │   args = tuple(args)                                                                 │
# │   253 │   │   self.key, sub_key = jax.random.split(self.key)                                     │
# │ ❱ 254 │   │   (w, tr) = gen_fn.importance(sub_key, sub_map, args)                                │
# │   255 │   │   self.choice_state[addr] = tr                                                       │
# │   256 │   │   self.score += tr.get_score()                                                       │
# │   257 │   │   self.weight += w                                                                   │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/plum/function.py:489 in __call__ │
# │                                                                                                  │
# │   486 │   │   pass                                                                               │
# │   487 │                                                                                          │
# │   488 │   def __call__(self, _, *args, **kw_args):                                               │
# │ ❱ 489 │   │   return self._f(self._instance, *args, **kw_args)                                   │
# │   490 │                                                                                          │
# │   491 │   def invoke(self, *types):                                                              │
# │   492 │   │   """See :meth:`.Function.invoke`."""                                                │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/plum/function.py:399 in __call__ │
# │                                                                                                  │
# │   396 │                                                                                          │
# │   397 │   def __call__(self, *args, **kw_args):                                                  │
# │   398 │   │   method, return_type = self._resolve_method_with_cache(args=args)                   │
# │ ❱ 399 │   │   return _convert(method(*args, **kw_args), return_type)                             │
# │   400 │                                                                                          │
# │   401 │   def _resolve_method_with_cache(                                                        │
# │   402 │   │   self,                                                                              │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/distributions/distribution.py │
# │ :163 in importance                                                                               │
# │                                                                                                  │
# │   160 │   │   chm: EmptyChoiceMap,                                                               │
# │   161 │   │   args: Tuple,                                                                       │
# │   162 │   ) -> Tuple[FloatArray, DistributionTrace]:                                             │
# │ ❱ 163 │   │   tr = self.simulate(key, args)                                                      │
# │   164 │   │   return (0.0, tr)                                                                   │
# │   165 │                                                                                          │
# │   166 │   @dispatch                                                                              │
# │ in simulate:50                                                                                   │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/distributions/distribution.py │
# │ :152 in simulate                                                                                 │
# │                                                                                                  │
# │   149 │   │   key: PRNGKey,                                                                      │
# │   150 │   │   args: Tuple,                                                                       │
# │   151 │   ) -> DistributionTrace:                                                                │
# │ ❱ 152 │   │   (w, v) = self.random_weighted(key, *args)                                          │
# │   153 │   │   tr = DistributionTrace(self, args, v, w)                                           │
# │   154 │   │   return tr                                                                          │
# │   155                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/distributions/distribution.py │
# │ :319 in random_weighted                                                                          │
# │                                                                                                  │
# │   316 │   │   """                                                                                │
# │   317 │                                                                                          │
# │   318 │   def random_weighted(self, key, *args, **kwargs):                                       │
# │ ❱ 319 │   │   v = self.sample(key, *args, **kwargs)                                              │
# │   320 │   │   w = self.logpdf(v, *args, **kwargs)                                                │
# │   321 │   │   return (w, v)                                                                      │
# │   322                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/Research/genjax/src/genjax/_src/dippl/__init__.py:80 in sample                     │
# │                                                                                                  │
# │    77 │   │   return ADEVDistribution(diff_logpdf, adev_prim)                                    │
# │    78 │                                                                                          │
# │    79 │   def sample(self, key, *args):                                                          │
# │ ❱  80 │   │   key, tracer_indicator = grab_key_and_tracer_indicator()                            │
# │    81 │   │   return sample_with_key(self.adev_primitive, key, tracer_indicator, *args)          │
# │    82 │                                                                                          │
# │    83 │   def logpdf(self, v, *args):                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/adevjax/core.py:140 in           │
# │ grab_key_and_tracer_indicator                                                                    │
# │                                                                                                  │
# │   137 │   assert _ADEV_STACK                                                                     │
# │   138 │                                                                                          │
# │   139 │   # Defer the behavior of this call to the handler.                                      │
# │ ❱ 140 │   return handle(None)                                                                    │
# │   141                                                                                            │
# │   142                                                                                            │
# │   143 def grab_key() -> Any:                                                                     │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/adevjax/core.py:91 in handle     │
# │                                                                                                  │
# │    88 def handle(msg):                                                                           │
# │    89 │   assert _ADEV_STACK                                                                     │
# │    90 │   handler = _ADEV_STACK[-1]                                                              │
# │ ❱  91 │   v = handler.process_message(msg)                                                       │
# │    92 │   return v                                                                               │
# │    93                                                                                            │
# │    94                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/adevjax/core.py:131 in           │
# │ process_message                                                                                  │
# │                                                                                                  │
# │   128 │   │   return SeedHandler(key, tracer_indicator)                                          │
# │   129 │                                                                                          │
# │   130 │   def process_message(self, msg):                                                        │
# │ ❱ 131 │   │   self.key, sub_key = jax.random.split(self.key)                                     │
# │   132 │   │   return sub_key, self._tracer_indicator                                             │
# │   133                                                                                            │
# │   134                                                                                            │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/random.py:270 in split  │
# │                                                                                                  │
# │    267   Returns:                                                                                │
# │    268 │   An array-like object of `num` new PRNG keys.                                          │
# │    269   """                                                                                     │
# │ ❱  270   key, wrapped = _check_prng_key(key)                                                     │
# │    271   return _return_prng_keys(wrapped, _split(key, num))                                     │
# │    272                                                                                           │
# │    273 def _key_data(keys: KeyArray) -> Array:                                                   │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/random.py:76 in         │
# │ _check_prng_key                                                                                  │
# │                                                                                                  │
# │     73 │   return key, False                                                                     │
# │     74   elif _arraylike(key):                                                                   │
# │     75 │   # Call random_wrap here to surface errors for invalid keys.                           │
# │ ❱   76 │   wrapped_key = prng.random_wrap(key, impl=default_prng_impl())                         │
# │     77 │   if config.jax_legacy_prng_key == 'error':                                             │
# │     78 │     raise ValueError(                                                                   │
# │     79 │   │   'Legacy uint32 key array passed as key to jax.random function. '                  │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/prng.py:877 in          │
# │ random_wrap                                                                                      │
# │                                                                                                  │
# │    874                                                                                           │
# │    875 def random_wrap(base_arr, *, impl):                                                       │
# │    876   _check_prng_key_data(impl, base_arr)                                                    │
# │ ❱  877   return random_wrap_p.bind(base_arr, impl=impl)                                          │
# │    878                                                                                           │
# │    879 random_wrap_p = core.Primitive('random_wrap')                                             │
# │    880 ad.defjvp_zero(random_wrap_p)                                                             │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/core.py:386 in bind     │
# │                                                                                                  │
# │    383   def bind(self, *args, **params):                                                        │
# │    384 │   assert (not config.jax_enable_checks or                                               │
# │    385 │   │   │   all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args     │
# │ ❱  386 │   return self.bind_with_trace(find_top_trace(args), args, params)                       │
# │    387                                                                                           │
# │    388   def bind_with_trace(self, trace, args, params):                                         │
# │    389 │   out = trace.process_primitive(self, map(trace.full_raise, args), params)              │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/core.py:1289 in         │
# │ find_top_trace                                                                                   │
# │                                                                                                  │
# │   1286   top_tracer = max((x for x in xs if isinstance(x, Tracer)),                              │
# │   1287 │   │   │   │   │   default=None, key=attrgetter('_trace.level'))                         │
# │   1288   if top_tracer is not None:                                                              │
# │ ❱ 1289 │   top_tracer._assert_live()                                                             │
# │   1290 │   top_main = top_tracer._trace.main                                                     │
# │   1291   else:                                                                                   │
# │   1292 │   top_main = None  # type: ignore                                                       │
# │                                                                                                  │
# │ /home/femtomc/miniconda3/envs/pyro/lib/python3.10/site-packages/jax/_src/interpreters/partial_ev │
# │ al.py:1621 in _assert_live                                                                       │
# │                                                                                                  │
# │   1618                                                                                           │
# │   1619   def _assert_live(self) -> None:                                                         │
# │   1620 │   if not self._trace.main.jaxpr_stack:  # type: ignore                                  │
# │ ❱ 1621 │     raise core.escaped_tracer_error(self, None)                                         │
# │   1622                                                                                           │
# │   1623   def get_referent(self):                                                                 │
# │   1624 │   frame = self._trace.frame                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnexpectedTracerError: Encountered an unexpected tracer. A function transformed by JAX had a side effect, allowing
# for a reference to an intermediate value with type uint32[2] wrapped in a DynamicJaxprTracer to escape the scope of
# the transformation.
# JAX transformations require that functions explicitly return their outputs, and disallow saving intermediate values
# to global state.
# ------------------------------
# The leaked intermediate value was created on line
# /home/femtomc/Research/genjax/src/genjax/_src/dippl/__init__.py:80 (sample).
# ------------------------------
# When the value was created, the final 5 stack frames (most recent last) excluding JAX-internal frames were:
# ------------------------------
# /home/femtomc/Research/genjax/src/genjax/_src/core/interpreters/staging.py:61 (cached_stage_dynamic)
# /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/builtin/builtin_primitives.py:55
# (_abstract_gen_fn_call)
# /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/distributions/distribution.py:125
# (__abstract_call__)
# /home/femtomc/Research/genjax/src/genjax/_src/generative_functions/distributions/distribution.py:319
# (random_weighted)
# /home/femtomc/Research/genjax/src/genjax/_src/dippl/__init__.py:80 (sample)
# ------------------------------
#
# To catch the leak earlier, try setting the environment variable JAX_CHECK_TRACER_LEAKS or using the
# `jax.checking_leaks` context manager.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.UnexpectedTracerError
